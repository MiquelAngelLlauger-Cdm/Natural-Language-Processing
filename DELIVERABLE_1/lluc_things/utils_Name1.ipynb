# %% [markdown]
# # Utils explanation (Name1)
# This notebook explains the functions in `utils.py` implemented by Name1.
# It demonstrates usage with small examples.

# %%
from utils import prepare_pair_texts, build_tfidf
sample = {'question1': ['How are you?'], 'question2': ['How do you do?']}
import pandas as pd
df = pd.DataFrame(sample)
texts = prepare_pair_texts(df)
vec, X = build_tfidf(texts)
print('TF-IDF shape:', X.shape)
