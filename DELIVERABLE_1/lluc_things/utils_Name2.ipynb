# %% [markdown]
# # Utils explanation (Name2)
# This notebook explains the functions in `utils.py` implemented by Name2.
# It demonstrates loading and saving models.

# %%
from utils import train_logreg, save_model, load_model
import numpy as np
X = np.random.randn(10,5)
y = np.random.randint(0,2,size=10)
clf = train_logreg(X, y)
save_model(clf, 'models/test_clf.pkl')
clf2 = load_model('models/test_clf.pkl')
print('Loaded model OK')
